# %% [markdown]
# # 環境確認
# 使用している環境を確認

# %%
import sys
print("Pythonのバージョン：",sys.version)
# Out:
# Pythonのバージョン： 3.7.12 (default, Jan 15 2022, 18:48:18)
# [GCC 7.5.0]

# %%
import torch
print("PyTorchのバージョン：", torch.__version__)
# Out:
# PyTorchのバージョン： 1.10.0+cu111

# %%
print("使用しているGPUの確認")
# !nvidia-smi
# Out:
# 使用しているGPUの確認
# Wed Feb  9 00:20:55 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 事前準備

# %%
# ライブラリのインポート
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# ランダムシードの設定
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Google Colab上に使用する訓練データ等を一時的に用意

# %%
import os 


# フォルダ「data」が存在しない場合は作成する
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
# MNISTの手書き数字画像をダウンロードし読み込みます
from sklearn.datasets import fetch_openml

# mnist = fetch_openml('mnist_784', version=1, data_home="./data/")  # data_homeは保存先を指定します
mnist = fetch_openml('mnist_784', version=1, data_home="./data/", as_frame=False)  
# Issue #153 2020年12月にリリースされたsklearn 0.24.0以降の仕様変更に合わせる場合

# %%
# データの取り出し
X = mnist.data
y = mnist.target

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# MNISTのデータの1つ目を可視化する
plt.imshow(X[0].reshape(28, 28), cmap='gray')
print("この画像データのラベルは{}です".format(y[0]))
# Out:
# この画像データのラベルは5です

# %%
# フォルダ「data」の下にフォルダ「img_78」を作成する
data_dir_path = "./data/img_78/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1
        
    # 7と8を200枚ずつ作成したらbreak
    if (count7>=max_num) and (count8>=max_num):
        break

# %%
# フォルダ「data」の下にフォルダ「test」を作成する
data_dir_path = "./data/test/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# 上記で7,8の画像を作成するのに使用したindexの最終値
i_start = i+1
print(i_start)
# Out:
# 2244

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count2=0
count7=0
count8=0
max_num=5  # 画像は5枚ずつ作成する

for i in range(i_start,len(X)):  # i_startから始める
    
    # 画像2の作成
    if (y[i] is "2") and (count2<max_num):
        file_path="./data/test/img_2_"+str(count2)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count2+=1
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/test/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/test/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1

# %%
# フォルダ「data」の下にフォルダ「img_78_28size」を作成する
data_dir_path = "./data/img_78_28size/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78_28size」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78_28size/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78_28size/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count8+=1
    
    if (count7>=max_num) and (count8>=max_num):
        break

# %%
# フォルダ「data」の下にフォルダ「test」を作成する
data_dir_path = "./data/test_28size/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# 上記で7,8の画像を作成するのに使用したindexの最終値
i_start = i+1
print(i_start)
# Out:
# 2244

# %%
# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count2=0
count7=0
count8=0
max_num=5  # 画像は5枚ずつ作成する

for i in range(i_start,len(X)):  # i_startから始める
    
    # 画像2の作成
    if (y[i] is "2") and (count2<max_num):
        file_path="./data/test_28size/img_2_"+str(count2)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count2+=1 
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/test_28size/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/test_28size/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count8+=1

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Linear(z_dim, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.Linear(1024, 7*7*128),
            nn.BatchNorm1d(7*7*128),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=128, out_channels=64,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(in_channels=64, out_channels=1,
                               kernel_size=4, stride=2, padding=1),
            nn.Tanh())
        # 白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)

        # 転置畳み込み層に入れるためにテンソルの形を整形
        out = out.view(z.shape[0], 128, 7, 7)
        out = self.layer3(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20)
G.train()

# 入力する乱数
# バッチノーマライゼーションがあるのでミニバッチ数は2以上
input_z = torch.randn(2, 20)

# 偽画像を出力
fake_images = G(input_z)  # torch.Size([2, 1, 28, 28])
img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20):
        super(Discriminator, self).__init__()

        # 画像側の入力処理
        self.x_layer1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.x_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        # 乱数側の入力処理
        self.z_layer1 = nn.Linear(z_dim, 512)

        # 最後の判定
        self.last1 = nn.Sequential(
            nn.Linear(3648, 1024),
            nn.LeakyReLU(0.1, inplace=True))

        self.last2 = nn.Linear(1024, 1)

    def forward(self, x, z):

        # 画像側の入力処理
        x_out = self.x_layer1(x)
        x_out = self.x_layer2(x_out)

        # 乱数側の入力処理
        z = z.view(z.shape[0], -1)
        z_out = self.z_layer1(z)

        # x_outとz_outを結合し、全結合層で判定
        x_out = x_out.view(-1, 64 * 7 * 7)
        out = torch.cat([x_out, z_out], dim=1)
        out = self.last1(out)

        feature = out  # 最後にチャネルを1つに集約する手前の情報
        feature = feature.view(feature.size()[0], -1)  # 2次元に変換

        out = self.last2(out)

        return out, feature

# %%
# 動作確認
D = Discriminator(z_dim=20)

# 偽画像を生成
input_z = torch.randn(2, 20)
fake_images = G(input_z)

# 偽画像をDに入力
d_out, _ = D(fake_images, input_z)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[0.4322],
#         [0.4629]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# # Encoderの実装
# 画像をzに変換する

# %%
class Encoder(nn.Module):

    def __init__(self, z_dim=20):
        super(Encoder, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3,
                      stride=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True))

        # ここまでで画像のサイズは7×7になっている
        self.last = nn.Linear(128 * 7 * 7, z_dim)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)

        # FCに入れるためにテンソルの形を整形
        out = out.view(-1, 128 * 7 * 7)
        out = self.last(out)

        return out

# %%
# 動作確認
E = Encoder(z_dim=20)

# 入力する画像データ
x = fake_images  # fake_imagesは上のGで作成したもの

# 画像からzをEncode
z = E(x)

print(z.shape)
print(z)
# Out:
# torch.Size([2, 20])
# tensor([[-0.0669, -0.2844, -0.3601,  0.1404, -0.2922, -0.4834, -0.0025,  0.0258,
#          -0.1298, -0.2613, -0.4292, -0.2584, -0.6141, -0.1440,  0.1142,  0.2175,
#           0.0730,  0.0323, -0.7176, -0.7410],
#         [ 0.4822,  0.3681, -0.0647, -0.0773,  0.0989,  0.3012,  0.8054,  0.4399,
#           1.0848, -0.2809,  0.0619, -0.3179, -0.2963, -0.1192,  0.6562, -0.1707,
#           0.1287, -0.6156,  0.3127, -0.4819]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 28, 28])

# %% [markdown]
# # 学習

# %%
# モデルを学習させる関数を作成


def train_model(G, D, E, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    lr_ge = 0.0001
    lr_d = 0.0001/4
    beta1, beta2 = 0.5, 0.999
    g_optimizer = torch.optim.Adam(G.parameters(), lr_ge, [beta1, beta2])
    e_optimizer = torch.optim.Adam(E.parameters(), lr_ge, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), lr_d, [beta1, beta2])

    # 誤差関数を定義
    # BCEWithLogitsLossは入力にシグモイド（logit）をかけてから、
    # バイナリークロスエントロピーを計算
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    E.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    E.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_e_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和



        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # ミニバッチサイズの1もしくは0のラベル役のテンソルを作成
            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # 真の画像を判定　
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images, input_z)

            # 誤差を計算
            # d_loss_real = criterion(d_out_real.view(-1), label_real)
            # d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            # d_loss = d_loss_real + d_loss_fake

            # Issue 144に従い修正
            # https://github.com/YutaroOgawa/pytorch_advanced/issues/144
            label_real = label_real.type_as(d_out_real.view(-1))
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            
            label_fake = label_fake.type_as(d_out_fake.view(-1))
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            
            d_loss = d_loss_real + d_loss_fake


            # バックプロパゲーション
            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images, input_z)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. Encoderの学習
            # --------------------
            # 真の画像のzを推定
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            # 誤差を計算
            e_loss = criterion(d_out_real.view(-1), label_fake)

            # バックプロパゲーション
            e_optimizer.zero_grad()
            e_loss.backward()
            e_optimizer.step()

            # --------------------
            # 4. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            epoch_e_loss += e_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        if epoch % 10==0:
            print('-------------')
            print('Epoch {}/{}'.format(epoch, num_epochs))
            print('-------------')
            print('（train）')
      
            t_epoch_finish = time.time()
            print('-------------')
            print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f} ||Epoch_E_Loss:{:.4f}'.format(
                epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size, epoch_e_loss/batch_size))
            print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
            t_epoch_start = time.time()

    print("総イテレーション回数:", iteration)

    return G, D, E

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        # 全結合層Linearの初期化
        m.bias.data.fill_(0)


# 初期化の実施
G.apply(weights_init)
E.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# 学習・検証を実行する
num_epochs = 1500  # 1500
G_update, D_update, E_update = train_model(
    G, D, E, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/1500
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.1485 ||Epoch_G_Loss:0.0789 ||Epoch_E_Loss:0.0767
# timer:  1.1250 sec.
# -------------
# Epoch 10/1500
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.1146 ||Epoch_G_Loss:0.0969 ||Epoch_E_Loss:0.1029
# timer:  0.5232 sec.
# -------------
# Epoch 20/1500
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.0581 ||Epoch_G_Loss:0.1579 ||Epoch_E_Loss:0.1732
# timer:  0.5227 sec.
# -------------
# Epoch 30/1500
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.0245 ||Epoch_G_Loss:0.2469 ||Epoch_E_Loss:0.2708
# timer:  0.5331 sec.
# -------------
# Epoch 40/1500
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.0116 ||Epoch_G_Loss:0.3192 ||Epoch_E_Loss:0.3671
# timer:  0.5270 sec.
# -------------
# Epoch 50/1500
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.0135 ||Epoch_G_Loss:0.3657 ||Epoch_E_Loss:0.3285
# timer:  0.5264 sec.
# -------------
# Epoch 60/1500
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.0070 ||Epoch_G_Loss:0.4165 ||Epoch_E_Loss:0.4053
# timer:  0.5254 sec.
# -------------
# Epoch 70/1500
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0073 ||Epoch_G_Loss:0.4243 ||Epoch_E_Loss:0.4051
# timer:  0.5409 sec.
# -------------
# Epoch 80/1500
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0095 ||Epoch_G_Loss:0.3879 ||Epoch_E_Loss:0.3942
# timer:  0.5329 sec.
# -------------
# Epoch 90/1500
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0272 ||Epoch_G_Loss:0.3135 ||Epoch_E_Loss:0.3128
# timer:  0.5309 sec.
# -------------
# Epoch 100/1500
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0556 ||Epoch_G_Loss:0.2846 ||Epoch_E_Loss:0.2896
# timer:  0.5287 sec.
# -------------
# Epoch 110/1500
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0533 ||Epoch_G_Loss:0.2577 ||Epoch_E_Loss:0.2615
# timer:  0.5284 sec.
# -------------
# Epoch 120/1500
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0635 ||Epoch_G_Loss:0.2148 ||Epoch_E_Loss:0.2451
# timer:  0.5342 sec.
# -------------
# Epoch 130/1500
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0611 ||Epoch_G_Loss:0.1994 ||Epoch_E_Loss:0.2203
# timer:  0.5362 sec.
# -------------
# Epoch 140/1500
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0730 ||Epoch_G_Loss:0.1945 ||Epoch_E_Loss:0.2191
# timer:  0.5221 sec.
# -------------
# Epoch 150/1500
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0607 ||Epoch_G_Loss:0.1992 ||Epoch_E_Loss:0.2242
# timer:  0.5275 sec.
# -------------
# Epoch 160/1500
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0543 ||Epoch_G_Loss:0.2118 ||Epoch_E_Loss:0.2238
# timer:  0.5231 sec.
# -------------
# Epoch 170/1500
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.1026 ||Epoch_G_Loss:0.1757 ||Epoch_E_Loss:0.1595
# timer:  0.5242 sec.
# -------------
# Epoch 180/1500
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0829 ||Epoch_G_Loss:0.1715 ||Epoch_E_Loss:0.1873
# timer:  0.5249 sec.
# -------------
# Epoch 190/1500
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.1174 ||Epoch_G_Loss:0.1530 ||Epoch_E_Loss:0.1788
# timer:  0.5209 sec.
# -------------
# Epoch 200/1500
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.1164 ||Epoch_G_Loss:0.1521 ||Epoch_E_Loss:0.1725
# timer:  0.5262 sec.
# -------------
# Epoch 210/1500
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.1173 ||Epoch_G_Loss:0.1250 ||Epoch_E_Loss:0.1474
# timer:  0.5272 sec.
# -------------
# Epoch 220/1500
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.1442 ||Epoch_G_Loss:0.1096 ||Epoch_E_Loss:0.1194
# timer:  0.5227 sec.
# -------------
# Epoch 230/1500
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.1253 ||Epoch_G_Loss:0.1219 ||Epoch_E_Loss:0.1193
# timer:  0.5200 sec.
# -------------
# Epoch 240/1500
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.1356 ||Epoch_G_Loss:0.1028 ||Epoch_E_Loss:0.1143
# timer:  0.5228 sec.
# -------------
# Epoch 250/1500
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.1273 ||Epoch_G_Loss:0.1177 ||Epoch_E_Loss:0.1185
# timer:  0.5303 sec.
# -------------
# Epoch 260/1500
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.1343 ||Epoch_G_Loss:0.1214 ||Epoch_E_Loss:0.1225
# timer:  0.5237 sec.
# -------------
# Epoch 270/1500
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.1511 ||Epoch_G_Loss:0.0985 ||Epoch_E_Loss:0.1153
# timer:  0.5273 sec.
# -------------
# Epoch 280/1500
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.1553 ||Epoch_G_Loss:0.1030 ||Epoch_E_Loss:0.1135
# timer:  0.5300 sec.
# -------------
# Epoch 290/1500
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.1515 ||Epoch_G_Loss:0.0987 ||Epoch_E_Loss:0.1117
# timer:  0.5377 sec.
# -------------
# Epoch 300/1500
# -------------
# （train）
# -------------
# epoch 300 || Epoch_D_Loss:0.1487 ||Epoch_G_Loss:0.1026 ||Epoch_E_Loss:0.1107
# timer:  0.5270 sec.
# -------------
# Epoch 310/1500
# -------------
# （train）
# -------------
# epoch 310 || Epoch_D_Loss:0.1583 ||Epoch_G_Loss:0.0962 ||Epoch_E_Loss:0.1076
# timer:  0.5283 sec.
# -------------
# Epoch 320/1500
# -------------
# （train）
# -------------
# epoch 320 || Epoch_D_Loss:0.1497 ||Epoch_G_Loss:0.0951 ||Epoch_E_Loss:0.1193
# timer:  0.5240 sec.
# -------------
# Epoch 330/1500
# -------------
# （train）
# -------------
# epoch 330 || Epoch_D_Loss:0.1947 ||Epoch_G_Loss:0.0817 ||Epoch_E_Loss:0.0945
# timer:  0.5204 sec.
# -------------
# Epoch 340/1500
# -------------
# （train）
# -------------
# epoch 340 || Epoch_D_Loss:0.1442 ||Epoch_G_Loss:0.0996 ||Epoch_E_Loss:0.1147
# timer:  0.5325 sec.
# -------------
# Epoch 350/1500
# -------------
# （train）
# -------------
# epoch 350 || Epoch_D_Loss:0.1559 ||Epoch_G_Loss:0.1039 ||Epoch_E_Loss:0.1128
# timer:  0.5285 sec.
# -------------
# Epoch 360/1500
# -------------
# （train）
# -------------
# epoch 360 || Epoch_D_Loss:0.1575 ||Epoch_G_Loss:0.0950 ||Epoch_E_Loss:0.1152
# timer:  0.5214 sec.
# -------------
# Epoch 370/1500
# -------------
# （train）
# -------------
# epoch 370 || Epoch_D_Loss:0.1657 ||Epoch_G_Loss:0.1022 ||Epoch_E_Loss:0.1107
# timer:  0.5285 sec.
# -------------
# Epoch 380/1500
# -------------
# （train）
# -------------
# epoch 380 || Epoch_D_Loss:0.1520 ||Epoch_G_Loss:0.0966 ||Epoch_E_Loss:0.1195
# timer:  0.5380 sec.
# -------------
# Epoch 390/1500
# -------------
# （train）
# -------------
# epoch 390 || Epoch_D_Loss:0.1710 ||Epoch_G_Loss:0.0904 ||Epoch_E_Loss:0.0999
# timer:  0.5255 sec.
# -------------
# Epoch 400/1500
# -------------
# （train）
# -------------
# epoch 400 || Epoch_D_Loss:0.1904 ||Epoch_G_Loss:0.0767 ||Epoch_E_Loss:0.0925
# timer:  0.5234 sec.
# -------------
# Epoch 410/1500
# -------------
# （train）
# -------------
# epoch 410 || Epoch_D_Loss:0.1758 ||Epoch_G_Loss:0.0825 ||Epoch_E_Loss:0.0963
# timer:  0.5444 sec.
# -------------
# Epoch 420/1500
# -------------
# （train）
# -------------
# epoch 420 || Epoch_D_Loss:0.1461 ||Epoch_G_Loss:0.0923 ||Epoch_E_Loss:0.1047
# timer:  0.5332 sec.
# -------------
# Epoch 430/1500
# -------------
# （train）
# -------------
# epoch 430 || Epoch_D_Loss:0.1424 ||Epoch_G_Loss:0.1019 ||Epoch_E_Loss:0.1016
# timer:  0.5323 sec.
# -------------
# Epoch 440/1500
# -------------
# （train）
# -------------
# epoch 440 || Epoch_D_Loss:0.1798 ||Epoch_G_Loss:0.0830 ||Epoch_E_Loss:0.0910
# timer:  0.5238 sec.
# -------------
# Epoch 450/1500
# -------------
# （train）
# -------------
# epoch 450 || Epoch_D_Loss:0.1810 ||Epoch_G_Loss:0.0769 ||Epoch_E_Loss:0.0845
# timer:  0.5246 sec.
# -------------
# Epoch 460/1500
# -------------
# （train）
# -------------
# epoch 460 || Epoch_D_Loss:0.1541 ||Epoch_G_Loss:0.0922 ||Epoch_E_Loss:0.0918
# timer:  0.5299 sec.
# -------------
# Epoch 470/1500
# -------------
# （train）
# -------------
# epoch 470 || Epoch_D_Loss:0.1480 ||Epoch_G_Loss:0.0969 ||Epoch_E_Loss:0.0970
# timer:  0.5284 sec.
# -------------
# Epoch 480/1500
# -------------
# （train）
# -------------
# epoch 480 || Epoch_D_Loss:0.1481 ||Epoch_G_Loss:0.0879 ||Epoch_E_Loss:0.0998
# timer:  0.5468 sec.
# -------------
# Epoch 490/1500
# -------------
# （train）
# -------------
# epoch 490 || Epoch_D_Loss:0.1484 ||Epoch_G_Loss:0.1049 ||Epoch_E_Loss:0.1058
# timer:  0.5370 sec.
# -------------
# Epoch 500/1500
# -------------
# （train）
# -------------
# epoch 500 || Epoch_D_Loss:0.1682 ||Epoch_G_Loss:0.0868 ||Epoch_E_Loss:0.0921
# timer:  0.5300 sec.
# -------------
# Epoch 510/1500
# -------------
# （train）
# -------------
# epoch 510 || Epoch_D_Loss:0.1436 ||Epoch_G_Loss:0.0877 ||Epoch_E_Loss:0.1106
# timer:  0.5296 sec.
# -------------
# Epoch 520/1500
# -------------
# （train）
# -------------
# epoch 520 || Epoch_D_Loss:0.1451 ||Epoch_G_Loss:0.0902 ||Epoch_E_Loss:0.1121
# timer:  0.5473 sec.
# -------------
# Epoch 530/1500
# -------------
# （train）
# -------------
# epoch 530 || Epoch_D_Loss:0.1527 ||Epoch_G_Loss:0.0986 ||Epoch_E_Loss:0.1009
# timer:  0.5458 sec.
# -------------
# Epoch 540/1500
# -------------
# （train）
# -------------
# epoch 540 || Epoch_D_Loss:0.1426 ||Epoch_G_Loss:0.1014 ||Epoch_E_Loss:0.1070
# timer:  0.5250 sec.
# -------------
# Epoch 550/1500
# -------------
# （train）
# -------------
# epoch 550 || Epoch_D_Loss:0.1236 ||Epoch_G_Loss:0.1155 ||Epoch_E_Loss:0.1178
# timer:  0.5352 sec.
# -------------
# Epoch 560/1500
# -------------
# （train）
# -------------
# epoch 560 || Epoch_D_Loss:0.1350 ||Epoch_G_Loss:0.1004 ||Epoch_E_Loss:0.1225
# timer:  0.5307 sec.
# -------------
# Epoch 570/1500
# -------------
# （train）
# -------------
# epoch 570 || Epoch_D_Loss:0.1324 ||Epoch_G_Loss:0.1014 ||Epoch_E_Loss:0.1172
# timer:  0.5243 sec.
# -------------
# Epoch 580/1500
# -------------
# （train）
# -------------
# epoch 580 || Epoch_D_Loss:0.1375 ||Epoch_G_Loss:0.1039 ||Epoch_E_Loss:0.1076
# timer:  0.5379 sec.
# -------------
# Epoch 590/1500
# -------------
# （train）
# -------------
# epoch 590 || Epoch_D_Loss:0.1580 ||Epoch_G_Loss:0.0897 ||Epoch_E_Loss:0.0882
# timer:  0.5218 sec.
# -------------
# Epoch 600/1500
# -------------
# （train）
# -------------
# epoch 600 || Epoch_D_Loss:0.1386 ||Epoch_G_Loss:0.0977 ||Epoch_E_Loss:0.1026
# timer:  0.5217 sec.
# -------------
# Epoch 610/1500
# -------------
# （train）
# -------------
# epoch 610 || Epoch_D_Loss:0.1315 ||Epoch_G_Loss:0.0966 ||Epoch_E_Loss:0.1072
# timer:  0.5387 sec.
# -------------
# Epoch 620/1500
# -------------
# （train）
# -------------
# epoch 620 || Epoch_D_Loss:0.1397 ||Epoch_G_Loss:0.0902 ||Epoch_E_Loss:0.0982
# timer:  0.5295 sec.
# -------------
# Epoch 630/1500
# -------------
# （train）
# -------------
# epoch 630 || Epoch_D_Loss:0.1285 ||Epoch_G_Loss:0.1007 ||Epoch_E_Loss:0.1080
# timer:  0.5225 sec.
# -------------
# Epoch 640/1500
# -------------
# （train）
# -------------
# epoch 640 || Epoch_D_Loss:0.1287 ||Epoch_G_Loss:0.1005 ||Epoch_E_Loss:0.1147
# timer:  0.5242 sec.
# -------------
# Epoch 650/1500
# -------------
# （train）
# -------------
# epoch 650 || Epoch_D_Loss:0.1204 ||Epoch_G_Loss:0.1041 ||Epoch_E_Loss:0.1146
# timer:  0.5256 sec.
# -------------
# Epoch 660/1500
# -------------
# （train）
# -------------
# epoch 660 || Epoch_D_Loss:0.1284 ||Epoch_G_Loss:0.0945 ||Epoch_E_Loss:0.1141
# timer:  0.5178 sec.
# -------------
# Epoch 670/1500
# -------------
# （train）
# -------------
# epoch 670 || Epoch_D_Loss:0.1179 ||Epoch_G_Loss:0.1049 ||Epoch_E_Loss:0.1198
# timer:  0.5304 sec.
# -------------
# Epoch 680/1500
# -------------
# （train）
# -------------
# epoch 680 || Epoch_D_Loss:0.1127 ||Epoch_G_Loss:0.1132 ||Epoch_E_Loss:0.1283
# timer:  0.5376 sec.
# -------------
# Epoch 690/1500
# -------------
# （train）
# -------------
# epoch 690 || Epoch_D_Loss:0.1337 ||Epoch_G_Loss:0.1112 ||Epoch_E_Loss:0.1066
# timer:  0.5340 sec.
# -------------
# Epoch 700/1500
# -------------
# （train）
# -------------
# epoch 700 || Epoch_D_Loss:0.1260 ||Epoch_G_Loss:0.1173 ||Epoch_E_Loss:0.1120
# timer:  0.5304 sec.
# -------------
# Epoch 710/1500
# -------------
# （train）
# -------------
# epoch 710 || Epoch_D_Loss:0.1326 ||Epoch_G_Loss:0.0999 ||Epoch_E_Loss:0.1115
# timer:  0.5265 sec.
# -------------
# Epoch 720/1500
# -------------
# （train）
# -------------
# epoch 720 || Epoch_D_Loss:0.1321 ||Epoch_G_Loss:0.1025 ||Epoch_E_Loss:0.1094
# timer:  0.5296 sec.
# -------------
# Epoch 730/1500
# -------------
# （train）
# -------------
# epoch 730 || Epoch_D_Loss:0.1383 ||Epoch_G_Loss:0.0986 ||Epoch_E_Loss:0.1066
# timer:  0.5355 sec.
# -------------
# Epoch 740/1500
# -------------
# （train）
# -------------
# epoch 740 || Epoch_D_Loss:0.1369 ||Epoch_G_Loss:0.0973 ||Epoch_E_Loss:0.1163
# timer:  0.5341 sec.
# -------------
# Epoch 750/1500
# -------------
# （train）
# -------------
# epoch 750 || Epoch_D_Loss:0.1385 ||Epoch_G_Loss:0.1008 ||Epoch_E_Loss:0.1106
# timer:  0.5369 sec.
# -------------
# Epoch 760/1500
# -------------
# （train）
# -------------
# epoch 760 || Epoch_D_Loss:0.1206 ||Epoch_G_Loss:0.1083 ||Epoch_E_Loss:0.1297
# timer:  0.5308 sec.
# -------------
# Epoch 770/1500
# -------------
# （train）
# -------------
# epoch 770 || Epoch_D_Loss:0.1548 ||Epoch_G_Loss:0.0880 ||Epoch_E_Loss:0.1089
# timer:  0.5219 sec.
# -------------
# Epoch 780/1500
# -------------
# （train）
# -------------
# epoch 780 || Epoch_D_Loss:0.1339 ||Epoch_G_Loss:0.0994 ||Epoch_E_Loss:0.1218
# timer:  0.5265 sec.
# -------------
# Epoch 790/1500
# -------------
# （train）
# -------------
# epoch 790 || Epoch_D_Loss:0.1241 ||Epoch_G_Loss:0.1083 ||Epoch_E_Loss:0.1232
# timer:  0.5253 sec.
# -------------
# Epoch 800/1500
# -------------
# （train）
# -------------
# epoch 800 || Epoch_D_Loss:0.1356 ||Epoch_G_Loss:0.1143 ||Epoch_E_Loss:0.1063
# timer:  0.5335 sec.
# -------------
# Epoch 810/1500
# -------------
# （train）
# -------------
# epoch 810 || Epoch_D_Loss:0.1199 ||Epoch_G_Loss:0.1042 ||Epoch_E_Loss:0.1237
# timer:  0.5386 sec.
# -------------
# Epoch 820/1500
# -------------
# （train）
# -------------
# epoch 820 || Epoch_D_Loss:0.1056 ||Epoch_G_Loss:0.1159 ||Epoch_E_Loss:0.1422
# timer:  0.5276 sec.
# -------------
# Epoch 830/1500
# -------------
# （train）
# -------------
# epoch 830 || Epoch_D_Loss:0.1305 ||Epoch_G_Loss:0.1038 ||Epoch_E_Loss:0.1255
# timer:  0.5246 sec.
# -------------
# Epoch 840/1500
# -------------
# （train）
# -------------
# epoch 840 || Epoch_D_Loss:0.1438 ||Epoch_G_Loss:0.0900 ||Epoch_E_Loss:0.1118
# timer:  0.5435 sec.
# -------------
# Epoch 850/1500
# -------------
# （train）
# -------------
# epoch 850 || Epoch_D_Loss:0.1337 ||Epoch_G_Loss:0.1032 ||Epoch_E_Loss:0.1113
# timer:  0.5359 sec.
# -------------
# Epoch 860/1500
# -------------
# （train）
# -------------
# epoch 860 || Epoch_D_Loss:0.1225 ||Epoch_G_Loss:0.1107 ||Epoch_E_Loss:0.1207
# timer:  0.5284 sec.
# -------------
# Epoch 870/1500
# -------------
# （train）
# -------------
# epoch 870 || Epoch_D_Loss:0.1313 ||Epoch_G_Loss:0.1014 ||Epoch_E_Loss:0.1116
# timer:  0.5368 sec.
# -------------
# Epoch 880/1500
# -------------
# （train）
# -------------
# epoch 880 || Epoch_D_Loss:0.1328 ||Epoch_G_Loss:0.0996 ||Epoch_E_Loss:0.1054
# timer:  0.5260 sec.
# -------------
# Epoch 890/1500
# -------------
# （train）
# -------------
# epoch 890 || Epoch_D_Loss:0.1260 ||Epoch_G_Loss:0.1052 ||Epoch_E_Loss:0.1082
# timer:  0.5207 sec.
# -------------
# Epoch 900/1500
# -------------
# （train）
# -------------
# epoch 900 || Epoch_D_Loss:0.1214 ||Epoch_G_Loss:0.1067 ||Epoch_E_Loss:0.1140
# timer:  0.5205 sec.
# -------------
# Epoch 910/1500
# -------------
# （train）
# -------------
# epoch 910 || Epoch_D_Loss:0.1074 ||Epoch_G_Loss:0.1226 ||Epoch_E_Loss:0.1261
# timer:  0.5221 sec.
# -------------
# Epoch 920/1500
# -------------
# （train）
# -------------
# epoch 920 || Epoch_D_Loss:0.1161 ||Epoch_G_Loss:0.1141 ||Epoch_E_Loss:0.1266
# timer:  0.5263 sec.
# -------------
# Epoch 930/1500
# -------------
# （train）
# -------------
# epoch 930 || Epoch_D_Loss:0.1090 ||Epoch_G_Loss:0.1335 ||Epoch_E_Loss:0.1239
# timer:  0.5262 sec.
# -------------
# Epoch 940/1500
# -------------
# （train）
# -------------
# epoch 940 || Epoch_D_Loss:0.1134 ||Epoch_G_Loss:0.1331 ||Epoch_E_Loss:0.1218
# timer:  0.5211 sec.
# -------------
# Epoch 950/1500
# -------------
# （train）
# -------------
# epoch 950 || Epoch_D_Loss:0.1161 ||Epoch_G_Loss:0.1042 ||Epoch_E_Loss:0.1234
# timer:  0.5219 sec.
# -------------
# Epoch 960/1500
# -------------
# （train）
# -------------
# epoch 960 || Epoch_D_Loss:0.1229 ||Epoch_G_Loss:0.1110 ||Epoch_E_Loss:0.1218
# timer:  0.5264 sec.
# -------------
# Epoch 970/1500
# -------------
# （train）
# -------------
# epoch 970 || Epoch_D_Loss:0.1378 ||Epoch_G_Loss:0.0964 ||Epoch_E_Loss:0.1112
# timer:  0.5329 sec.
# -------------
# Epoch 980/1500
# -------------
# （train）
# -------------
# epoch 980 || Epoch_D_Loss:0.1051 ||Epoch_G_Loss:0.1300 ||Epoch_E_Loss:0.1250
# timer:  0.5371 sec.
# -------------
# Epoch 990/1500
# -------------
# （train）
# -------------
# epoch 990 || Epoch_D_Loss:0.1046 ||Epoch_G_Loss:0.1272 ||Epoch_E_Loss:0.1279
# timer:  0.5309 sec.
# -------------
# Epoch 1000/1500
# -------------
# （train）
# -------------
# epoch 1000 || Epoch_D_Loss:0.1086 ||Epoch_G_Loss:0.1118 ||Epoch_E_Loss:0.1278
# timer:  0.5269 sec.
# -------------
# Epoch 1010/1500
# -------------
# （train）
# -------------
# epoch 1010 || Epoch_D_Loss:0.1171 ||Epoch_G_Loss:0.1165 ||Epoch_E_Loss:0.1155
# timer:  0.5307 sec.
# -------------
# Epoch 1020/1500
# -------------
# （train）
# -------------
# epoch 1020 || Epoch_D_Loss:0.1335 ||Epoch_G_Loss:0.1026 ||Epoch_E_Loss:0.1171
# timer:  0.5322 sec.
# -------------
# Epoch 1030/1500
# -------------
# （train）
# -------------
# epoch 1030 || Epoch_D_Loss:0.1303 ||Epoch_G_Loss:0.1071 ||Epoch_E_Loss:0.1253
# timer:  0.5367 sec.
# -------------
# Epoch 1040/1500
# -------------
# （train）
# -------------
# epoch 1040 || Epoch_D_Loss:0.1190 ||Epoch_G_Loss:0.1114 ||Epoch_E_Loss:0.1224
# timer:  0.5371 sec.
# -------------
# Epoch 1050/1500
# -------------
# （train）
# -------------
# epoch 1050 || Epoch_D_Loss:0.1076 ||Epoch_G_Loss:0.1305 ||Epoch_E_Loss:0.1325
# timer:  0.5235 sec.
# -------------
# Epoch 1060/1500
# -------------
# （train）
# -------------
# epoch 1060 || Epoch_D_Loss:0.1323 ||Epoch_G_Loss:0.1149 ||Epoch_E_Loss:0.1103
# timer:  0.5235 sec.
# -------------
# Epoch 1070/1500
# -------------
# （train）
# -------------
# epoch 1070 || Epoch_D_Loss:0.1188 ||Epoch_G_Loss:0.1162 ||Epoch_E_Loss:0.1257
# timer:  0.5273 sec.
# -------------
# Epoch 1080/1500
# -------------
# （train）
# -------------
# epoch 1080 || Epoch_D_Loss:0.1082 ||Epoch_G_Loss:0.1135 ||Epoch_E_Loss:0.1279
# timer:  0.5304 sec.
# -------------
# Epoch 1090/1500
# -------------
# （train）
# -------------
# epoch 1090 || Epoch_D_Loss:0.1231 ||Epoch_G_Loss:0.1040 ||Epoch_E_Loss:0.1157
# timer:  0.5237 sec.
# -------------
# Epoch 1100/1500
# -------------
# （train）
# -------------
# epoch 1100 || Epoch_D_Loss:0.1171 ||Epoch_G_Loss:0.1194 ||Epoch_E_Loss:0.1174
# timer:  0.5226 sec.
# -------------
# Epoch 1110/1500
# -------------
# （train）
# -------------
# epoch 1110 || Epoch_D_Loss:0.1130 ||Epoch_G_Loss:0.1218 ||Epoch_E_Loss:0.1173
# timer:  0.5262 sec.
# -------------
# Epoch 1120/1500
# -------------
# （train）
# -------------
# epoch 1120 || Epoch_D_Loss:0.1283 ||Epoch_G_Loss:0.1202 ||Epoch_E_Loss:0.1138
# timer:  0.5274 sec.
# -------------
# Epoch 1130/1500
# -------------
# （train）
# -------------
# epoch 1130 || Epoch_D_Loss:0.1044 ||Epoch_G_Loss:0.1329 ||Epoch_E_Loss:0.1305
# timer:  0.5303 sec.
# -------------
# Epoch 1140/1500
# -------------
# （train）
# -------------
# epoch 1140 || Epoch_D_Loss:0.1192 ||Epoch_G_Loss:0.1146 ||Epoch_E_Loss:0.1262
# timer:  0.5233 sec.
# -------------
# Epoch 1150/1500
# -------------
# （train）
# -------------
# epoch 1150 || Epoch_D_Loss:0.1081 ||Epoch_G_Loss:0.1167 ||Epoch_E_Loss:0.1273
# timer:  0.5248 sec.
# -------------
# Epoch 1160/1500
# -------------
# （train）
# -------------
# epoch 1160 || Epoch_D_Loss:0.1243 ||Epoch_G_Loss:0.1072 ||Epoch_E_Loss:0.1191
# timer:  0.5324 sec.
# -------------
# Epoch 1170/1500
# -------------
# （train）
# -------------
# epoch 1170 || Epoch_D_Loss:0.1158 ||Epoch_G_Loss:0.1166 ||Epoch_E_Loss:0.1339
# timer:  0.5215 sec.
# -------------
# Epoch 1180/1500
# -------------
# （train）
# -------------
# epoch 1180 || Epoch_D_Loss:0.1107 ||Epoch_G_Loss:0.1304 ||Epoch_E_Loss:0.1250
# timer:  0.5318 sec.
# -------------
# Epoch 1190/1500
# -------------
# （train）
# -------------
# epoch 1190 || Epoch_D_Loss:0.1167 ||Epoch_G_Loss:0.1218 ||Epoch_E_Loss:0.1240
# timer:  0.5237 sec.
# -------------
# Epoch 1200/1500
# -------------
# （train）
# -------------
# epoch 1200 || Epoch_D_Loss:0.1204 ||Epoch_G_Loss:0.1247 ||Epoch_E_Loss:0.1257
# timer:  0.5286 sec.
# -------------
# Epoch 1210/1500
# -------------
# （train）
# -------------
# epoch 1210 || Epoch_D_Loss:0.1032 ||Epoch_G_Loss:0.1305 ||Epoch_E_Loss:0.1411
# timer:  0.5320 sec.
# -------------
# Epoch 1220/1500
# -------------
# （train）
# -------------
# epoch 1220 || Epoch_D_Loss:0.1175 ||Epoch_G_Loss:0.1210 ||Epoch_E_Loss:0.1243
# timer:  0.5211 sec.
# -------------
# Epoch 1230/1500
# -------------
# （train）
# -------------
# epoch 1230 || Epoch_D_Loss:0.1162 ||Epoch_G_Loss:0.1148 ||Epoch_E_Loss:0.1467
# timer:  0.5214 sec.
# -------------
# Epoch 1240/1500
# -------------
# （train）
# -------------
# epoch 1240 || Epoch_D_Loss:0.1609 ||Epoch_G_Loss:0.1060 ||Epoch_E_Loss:0.1184
# timer:  0.5277 sec.
# -------------
# Epoch 1250/1500
# -------------
# （train）
# -------------
# epoch 1250 || Epoch_D_Loss:0.0916 ||Epoch_G_Loss:0.1312 ||Epoch_E_Loss:0.1599
# timer:  0.5240 sec.
# -------------
# Epoch 1260/1500
# -------------
# （train）
# -------------
# epoch 1260 || Epoch_D_Loss:0.1143 ||Epoch_G_Loss:0.1234 ||Epoch_E_Loss:0.1343
# timer:  0.5286 sec.
# -------------
# Epoch 1270/1500
# -------------
# （train）
# -------------
# epoch 1270 || Epoch_D_Loss:0.1221 ||Epoch_G_Loss:0.1065 ||Epoch_E_Loss:0.1360
# timer:  0.5166 sec.
# -------------
# Epoch 1280/1500
# -------------
# （train）
# -------------
# epoch 1280 || Epoch_D_Loss:0.1172 ||Epoch_G_Loss:0.1159 ||Epoch_E_Loss:0.1312
# timer:  0.5303 sec.
# -------------
# Epoch 1290/1500
# -------------
# （train）
# -------------
# epoch 1290 || Epoch_D_Loss:0.1125 ||Epoch_G_Loss:0.1211 ||Epoch_E_Loss:0.1363
# timer:  0.5210 sec.
# -------------
# Epoch 1300/1500
# -------------
# （train）
# -------------
# epoch 1300 || Epoch_D_Loss:0.1113 ||Epoch_G_Loss:0.1198 ||Epoch_E_Loss:0.1378
# timer:  0.5234 sec.
# -------------
# Epoch 1310/1500
# -------------
# （train）
# -------------
# epoch 1310 || Epoch_D_Loss:0.0959 ||Epoch_G_Loss:0.1331 ||Epoch_E_Loss:0.1439
# timer:  0.5256 sec.
# -------------
# Epoch 1320/1500
# -------------
# （train）
# -------------
# epoch 1320 || Epoch_D_Loss:0.1305 ||Epoch_G_Loss:0.1109 ||Epoch_E_Loss:0.1175
# timer:  0.5192 sec.
# -------------
# Epoch 1330/1500
# -------------
# （train）
# -------------
# epoch 1330 || Epoch_D_Loss:0.1049 ||Epoch_G_Loss:0.1263 ||Epoch_E_Loss:0.1354
# timer:  0.5348 sec.
# -------------
# Epoch 1340/1500
# -------------
# （train）
# -------------
# epoch 1340 || Epoch_D_Loss:0.0950 ||Epoch_G_Loss:0.1243 ||Epoch_E_Loss:0.1436
# timer:  0.5297 sec.
# -------------
# Epoch 1350/1500
# -------------
# （train）
# -------------
# epoch 1350 || Epoch_D_Loss:0.0989 ||Epoch_G_Loss:0.1177 ||Epoch_E_Loss:0.1440
# timer:  0.5259 sec.
# -------------
# Epoch 1360/1500
# -------------
# （train）
# -------------
# epoch 1360 || Epoch_D_Loss:0.0959 ||Epoch_G_Loss:0.1350 ||Epoch_E_Loss:0.1391
# timer:  0.5283 sec.
# -------------
# Epoch 1370/1500
# -------------
# （train）
# -------------
# epoch 1370 || Epoch_D_Loss:0.0890 ||Epoch_G_Loss:0.1477 ||Epoch_E_Loss:0.1505
# timer:  0.5221 sec.
# -------------
# Epoch 1380/1500
# -------------
# （train）
# -------------
# epoch 1380 || Epoch_D_Loss:0.1016 ||Epoch_G_Loss:0.1412 ||Epoch_E_Loss:0.1446
# timer:  0.5306 sec.
# -------------
# Epoch 1390/1500
# -------------
# （train）
# -------------
# epoch 1390 || Epoch_D_Loss:0.1252 ||Epoch_G_Loss:0.1173 ||Epoch_E_Loss:0.1240
# timer:  0.5227 sec.
# -------------
# Epoch 1400/1500
# -------------
# （train）
# -------------
# epoch 1400 || Epoch_D_Loss:0.1140 ||Epoch_G_Loss:0.1159 ||Epoch_E_Loss:0.1388
# timer:  0.5253 sec.
# -------------
# Epoch 1410/1500
# -------------
# （train）
# -------------
# epoch 1410 || Epoch_D_Loss:0.1033 ||Epoch_G_Loss:0.1343 ||Epoch_E_Loss:0.1444
# timer:  0.5228 sec.
# -------------
# Epoch 1420/1500
# -------------
# （train）
# -------------
# epoch 1420 || Epoch_D_Loss:0.0924 ||Epoch_G_Loss:0.1465 ||Epoch_E_Loss:0.1517
# timer:  0.5217 sec.
# -------------
# Epoch 1430/1500
# -------------
# （train）
# -------------
# epoch 1430 || Epoch_D_Loss:0.1097 ||Epoch_G_Loss:0.1274 ||Epoch_E_Loss:0.1483
# timer:  0.5192 sec.
# -------------
# Epoch 1440/1500
# -------------
# （train）
# -------------
# epoch 1440 || Epoch_D_Loss:0.1091 ||Epoch_G_Loss:0.1418 ||Epoch_E_Loss:0.1381
# timer:  0.5276 sec.
# -------------
# Epoch 1450/1500
# -------------
# （train）
# -------------
# epoch 1450 || Epoch_D_Loss:0.1101 ||Epoch_G_Loss:0.1135 ||Epoch_E_Loss:0.1390
# timer:  0.5374 sec.
# -------------
# Epoch 1460/1500
# -------------
# （train）
# -------------
# epoch 1460 || Epoch_D_Loss:0.1013 ||Epoch_G_Loss:0.1343 ||Epoch_E_Loss:0.1389
# timer:  0.5216 sec.
# -------------
# Epoch 1470/1500
# -------------
# （train）
# -------------
# epoch 1470 || Epoch_D_Loss:0.0991 ||Epoch_G_Loss:0.1361 ||Epoch_E_Loss:0.1434
# timer:  0.5354 sec.
# -------------
# Epoch 1480/1500
# -------------
# （train）
# -------------
# epoch 1480 || Epoch_D_Loss:0.0972 ||Epoch_G_Loss:0.1431 ||Epoch_E_Loss:0.1503
# timer:  0.5267 sec.
# -------------
# Epoch 1490/1500
# -------------
# （train）
# -------------
# epoch 1490 || Epoch_D_Loss:0.1039 ||Epoch_G_Loss:0.1400 ||Epoch_E_Loss:0.1408
# timer:  0.5223 sec.
# 総イテレーション回数: 10501

# %%
# 生成画像と訓練データを可視化する
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
G_update.eval()
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %%
# テスト用のDataLoaderの作成

def make_test_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(5):
        img_path = "./data/test_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_2_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


# ファイルリストを作成
test_img_list = make_test_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
test_dataset = GAN_Img_Dataset(
    file_list=test_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 5

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)

# %%
# テストデータの確認
batch_iterator = iter(test_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

# %%
def Anomaly_score(x, fake_img, z_out_real, D, Lambda=0.1):

    # テスト画像xと生成画像fake_imgのピクセルレベルの差の絶対値を求めて、ミニバッチごとに和を求める
    residual_loss = torch.abs(x-fake_img)
    residual_loss = residual_loss.view(residual_loss.size()[0], -1)
    residual_loss = torch.sum(residual_loss, dim=1)

    # テスト画像xと生成画像fake_imgを識別器Dに入力し、特徴量マップを取り出す

    _, x_feature = D(x, z_out_real)
    _, G_feature = D(fake_img, z_out_real)

    # テスト画像xと生成画像fake_imgの特徴量の差の絶対値を求めて、ミニバッチごとに和を求める
    discrimination_loss = torch.abs(x_feature-G_feature)
    discrimination_loss = discrimination_loss.view(
        discrimination_loss.size()[0], -1)
    discrimination_loss = torch.sum(discrimination_loss, dim=1)

    # ミニバッチごとに2種類の損失を足し算する
    loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_loss

    # ミニバッチ全部の損失を求める
    total_loss = torch.sum(loss_each)

    return total_loss, loss_each, residual_loss

# %%
# 異常検知したい画像
x = imges[0:5]
x = x.to(device)

# 教師データの画像をエンコードしてzにしてから、Gで生成
E_update.eval()
G_update.eval()
z_out_real = E_update(imges.to(device))
imges_reconstract = G_update(z_out_real)

# 損失を求める
loss, loss_each, residual_loss_each = Anomaly_score(
    x, imges_reconstract, z_out_real, D_update, Lambda=0.1)

# 損失の計算。トータルの損失
loss_each = loss_each.cpu().detach().numpy()
print("total loss：", np.round(loss_each, 0))

# 画像を可視化
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(imges_reconstract[i][0].cpu().detach().numpy(), 'gray')
# Out:
# total loss： [160. 254. 289. 203. 242.]
